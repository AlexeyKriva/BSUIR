# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

PATH = "EPL Standings 2000-2022.csv"
dataset = pd.read_csv(PATH)

for column in dataset:
    if type(dataset[column][0]) is str:
        dataset[column] = pd.factorize(dataset[column])[0]
        
# sns.set_style('whitegrid')
# sns.set_palette('deep')

# sns.lineplot(
#     x=dataset["Pos"],
#     y=dataset["W"],
# )

# plt.title('График зависимости')
# plt.xlabel('Параметр Pos')
# plt.ylabel('Параметр W')
# plt.show()

# pos = np.array(dataset["Pos"]).reshape(-1, 1)
# w = np.array(dataset["W"]).reshape(-1, 1)


# DEGREES = 2

# regression = make_pipeline(PolynomialFeatures(DEGREES), LinearRegression())
# regression.fit(pos, w)
# predictions = regression.predict(pos)
# mean_squared_error = np.mean((predictions - np.array(w)) ** 2)
# print(f'Среднеквадратическая ошибка = {mean_squared_error}')
# sns.lineplot(
#     x=dataset["Pos"],
#     y=dataset["W"],
#     linestyle="solid"
# )

# sns.lineplot(
#     x=dataset["Pos"],
#     y=predictions.reshape(-1),
#     linestyle="dotted"
# )

# plt.title(
#     'График зависимости\n\n'
#     'Сплошная линия - эталонные значения\n'
#     'точечная линия - предсказания регрессии'
# )
# plt.xlabel('Параметр Pos')
# plt.ylabel('Параметр W')
# plt.show()

# x_parameters = np.append(
#     regression['linearregression'].intercept_[0],
#     regression['linearregression'].coef_[0][1:]
# )

# x_parameters

# print("Уравнение регрессии(Pos, W): " + str(x_parameters[2])+"*x^2"+str(x_parameters[1])+"*x+"+str(x_parameters[0]))







# sns.set_style('whitegrid')
# sns.set_palette('deep')

# sns.lineplot(
#     x=dataset["Pos"],
#     y=dataset["L"],
# )

# plt.title('График зависимости')
# plt.xlabel('Параметр Pos')
# plt.ylabel('Параметр L')
# plt.show()

# pos = np.array(dataset["Pos"]).reshape(-1, 1)
# w = np.array(dataset["L"]).reshape(-1, 1)


# DEGREES = 2

# regression = make_pipeline(PolynomialFeatures(DEGREES), LinearRegression())
# regression.fit(pos, w)
# predictions = regression.predict(pos)
# mean_squared_error = np.mean((predictions - np.array(w)) ** 2)
# print(f'Среднеквадратическая ошибка = {mean_squared_error}')
# sns.lineplot(
#     x=dataset["Pos"],
#     y=dataset["L"],
#     linestyle="solid"
# )

# sns.lineplot(
#     x=dataset["Pos"],
#     y=predictions.reshape(-1),
#     linestyle="dotted"
# )

# plt.title(
#     'График зависимости\n\n'
#     'Сплошная линия - эталонные значения\n'
#     'точечная линия - предсказания регрессии'
# )
# plt.xlabel('Параметр Pos')
# plt.ylabel('Параметр L')
# plt.show()

# x_parameters = np.append(
#     regression['linearregression'].intercept_[0],
#     regression['linearregression'].coef_[0][1:]
# )

# x_parameters

# print("Уравнение регрессии(Pos, L): " + str(x_parameters[2])+"*x^2"+str(x_parameters[1])+"*x+"+str(x_parameters[0]))







# sns.set_style('whitegrid')
# sns.set_palette('deep')

# sns.lineplot(
#     x=dataset["Pos"],
#     y=dataset["Pts"],
# )

# plt.title('График зависимости')
# plt.xlabel('Параметр Pos')
# plt.ylabel('Параметр Pts')
# plt.show()

# pos = np.array(dataset["Pos"]).reshape(-1, 1)
# w = np.array(dataset["Pts"]).reshape(-1, 1)


# DEGREES = 2

# regression = make_pipeline(PolynomialFeatures(DEGREES), LinearRegression())
# regression.fit(pos, w)
# predictions = regression.predict(pos)
# mean_squared_error = np.mean((predictions - np.array(w)) ** 2)
# print(f'Среднеквадратическая ошибка = {mean_squared_error}')
# sns.lineplot(
#     x=dataset["Pos"],
#     y=dataset["Pts"],
#     linestyle="solid"
# )

# sns.lineplot(
#     x=dataset["Pos"],
#     y=predictions.reshape(-1),
#     linestyle="dotted"
# )

# plt.title(
#     'График зависимости\n\n'
#     'Сплошная линия - эталонные значения\n'
#     'точечная линия - предсказания регрессии'
# )
# plt.xlabel('Параметр Pos')
# plt.ylabel('Параметр Pts')
# plt.show()

# x_parameters = np.append(
#     regression['linearregression'].intercept_[0],
#     regression['linearregression'].coef_[0][1:]
# )

# x_parameters

# print("Уравнение регрессии(Pos, Pts): " + str(x_parameters[2])+"*x^2"+str(x_parameters[1])+"*x+"+str(x_parameters[0]))







# sns.set_style('whitegrid')
# sns.set_palette('deep')

# sns.lineplot(
#     x=dataset["Pos"],
#     y=dataset["GF"],
# )

# plt.title('График зависимости')
# plt.xlabel('Параметр Pos')
# plt.ylabel('Параметр GF')
# plt.show()

# pos = np.array(dataset["Pos"]).reshape(-1, 1)
# w = np.array(dataset["GF"]).reshape(-1, 1)


# DEGREES = 2

# regression = make_pipeline(PolynomialFeatures(DEGREES), LinearRegression())
# regression.fit(pos, w)
# predictions = regression.predict(pos)
# mean_squared_error = np.mean((predictions - np.array(w)) ** 2)
# print(f'Среднеквадратическая ошибка = {mean_squared_error}')
# sns.lineplot(
#     x=dataset["Pos"],
#     y=dataset["GF"],
#     linestyle="solid"
# )

# sns.lineplot(
#     x=dataset["Pos"],
#     y=predictions.reshape(-1),
#     linestyle="dotted"
# )

# plt.title(
#     'График зависимости\n\n'
#     'Сплошная линия - эталонные значения\n'
#     'точечная линия - предсказания регрессии'
# )
# plt.xlabel('Параметр Pos')
# plt.ylabel('Параметр GF')
# plt.show()

# x_parameters = np.append(
#     regression['linearregression'].intercept_[0],
#     regression['linearregression'].coef_[0][1:]
# )

# x_parameters

# print("Уравнение регрессии(Pos, GF): " + str(x_parameters[2])+"*x^2"+str(x_parameters[1])+"*x+"+str(x_parameters[0]))








# sns.set_style('whitegrid')
# sns.set_palette('deep')

# sns.lineplot(
#     x=dataset["Pos"],
#     y=dataset["GA"],
# )

# plt.title('График зависимости')
# plt.xlabel('Параметр Pos')
# plt.ylabel('Параметр GA')
# plt.show()

# pos = np.array(dataset["Pos"]).reshape(-1, 1)
# w = np.array(dataset["GA"]).reshape(-1, 1)


# DEGREES = 2

# regression = make_pipeline(PolynomialFeatures(DEGREES), LinearRegression())
# regression.fit(pos, w)
# predictions = regression.predict(pos)
# mean_squared_error = np.mean((predictions - np.array(w)) ** 2)
# print(f'Среднеквадратическая ошибка = {mean_squared_error}')
# sns.lineplot(
#     x=dataset["Pos"],
#     y=dataset["GA"],
#     linestyle="solid"
# )

# sns.lineplot(
#     x=dataset["Pos"],
#     y=predictions.reshape(-1),
#     linestyle="dotted"
# )

# plt.title(
#     'График зависимости\n\n'
#     'Сплошная линия - эталонные значения\n'
#     'точечная линия - предсказания регрессии'
# )
# plt.xlabel('Параметр Pos')
# plt.ylabel('Параметр GA')
# plt.show()

# x_parameters = np.append(
#     regression['linearregression'].intercept_[0],
#     regression['linearregression'].coef_[0][1:]
# )

# x_parameters

# print("Уравнение регрессии(Pos, GA): " + str(x_parameters[2])+"*x^2"+str(x_parameters[1])+"*x+"+str(x_parameters[0]))



top_5_positions = dataset.query('Pos <= 5')
print(top_5_positions)

for index, row in dataset.iterrows():
    if row["Pos"] <= 5:
        print(dataset.values[index])
        
for index, row in dataset.iterrows():
    if row["Pos"] <= 5:
        print(row)
        
for index, row in dataset.iterrows():
    if row["Pos"] <= 5:
        print(dataset.iloc[index])
        
for index, row in dataset.iterrows():
    if row["Pos"] <= 5:
        print(dataset.loc[index])
        
for index, row in dataset.iterrows():
    if row["Pos"] <= 5:
        print(row.to_dict())
# Out:
#      Season  Pos  Team  Pld   W   D   L  GF  GA  GD  Pts  \
# 0         0    1     0   38  24   8   6  79  31  48   80
# 1         0    2     1   38  20  10   8  63  38  25   70
# 2         0    3     2   38  20   9   9  71  39  32   69
# 3         0    4     3   38  20   8  10  64  43  21   68
# 4         0    5     4   38  20   6  12  57  42  15   66
# ..      ...  ...   ...  ...  ..  ..  ..  ..  ..  ..  ...
# 420      21    1    17   38  29   6   3  99  26  73   93
# 421      21    2     2   38  28   8   2  94  26  68   92
# 422      21    3     5   38  21  11   6  76  33  43   74
# 423      21    4    11   38  22   5  11  69  40  29   71
# 424      21    5     1   38  22   3  13  61  48  13   69
#
#      Qualification or relegation
# 0                              0
# 1                              0
# 2                              1
# 3                              2
# 4                              2
# ..                           ...
# 420                           11
# ...
